# %% [markdown]
# # Tuples
#
# * Tuples are **immutable ,unordered collection of items **enclosed in closed brackets
# * The elements of Tuples are also seperated by comma and can hold items of any datatype
# * Just like arrays and lists Elements of tuples are located in adjacent memory locations to guarantee extreme efficienty

# %% [markdown]
# ## Contents
#   ##### 1.Creating an empty Tuple
#   ##### 2.Creating a Tuple with elements
#   ##### 3.Accessing /Traversing the Tuple
#   ##### 4.Update/Insert a Tuple in python
#   ##### 5.Slicing  Concept in Tuple
#   ##### 6.Deletion methods in Tuple
#   ##### 7.Lists and Tuples {similarities and differences}
#
# ---

# %% [markdown]
# ### 1.Creating an empty Tuple

# %%
# with the help of parenthesis
empty_Tuple=()
type(empty_Tuple)
# Out:
# tuple

# %%
# Creating tuple with only one element
tup=('a',)
print(type(tup))
# Out:
# <class 'tuple'>

# %%
# creating empty tuple using constructor tuple()
tup=tuple()
tup
# Out:
# ()

# %% [markdown]
# ### 2.Creating a Tuple with elements

# %%
ing=(1,2,3,4,5,6,7)
stg=('ab','bc','cd')
intstr= (1,2,'ab',12.5,[8,9,1,0], {1:3,4:5}, (4,5,0)) # tuple holds list,dictionary,tuple inside tuple
print(type(ing))
print(type(stg))
print(type(intstr))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# ---

# %% [markdown]
# ### 3.Accessing /Traversing the Tuple
#
# Accesing the element can be done either using forward indexing or reverse indexing

# %%
# Accessing

nts= (1,2,'ab',12.5)
print(nts[0])  # forward indexing
print(nts[-2]) # backward indexing
print(type(nts))
# Out:
# 1
# ab
# <class 'tuple'>

# %%
#Traversing -->visiting each element atleast once in the Tuple (traversing can be done using for loop)

#using membership operator in
nts= (1,2,'ab',12.5)
for i in nts:
  print(i)
# Out:
# 1
# 2
# ab
# 12.5

# %% [markdown]
# ⚡Is it possible to loop towards an empty Tuple?

# %% [markdown]
# ### 4.Update/Insert a Tuple in python
# Updating or inserting is not possible in tuple

# %%
# Updating elements --> without changing the memoruy location we update a value to a given location

Tuple1=(12,35,'hgf',13.65, 854)
Tuple1(2)='bmw'
Tuple1
# Out:
#   File "<ipython-input-14-4da685462010>", line 4
#     Tuple1(2)='bmw'
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### 5.Slicing  Concept in Tuple
# slicing is possible only to access or traverse but not to update or delete
#     syntax-->(Tuple1(start:stop:step))

# %%
Tuple1=(12,35,'hgf',13.65, 854)
Tuple1
# Out:
# (12, 35, 'hgf', 13.65, 854)

# %%
# first two elements
print(Tuple1[0:])
# Out:
# (12, 35, 'hgf', 13.65, 854)

# %%
#second element to len of Tuple
print(Tuple1[1:])
# Out:
# (35, 'hgf', 13.65, 854)

# %%
# All elements
print(Tuple1[:])
# Out:
# (12, 35, 'hgf', 13.65, 854)

# %%
#In steps of two
print(Tuple1[::2])
# Out:
# (12, 'hgf', 854)

# %%
#reversing the Tuple elements
print(Tuple1[::-1])
# Out:
# (854, 13.65, 'hgf', 35, 12)

# %% [markdown]
# ### 6.Deletion methods in Tuple

# %%
#delete method works on entire Tuple
#syntax--> del Tuple
Tuple1=(12,35,'hgf',13.65, 854)
del Tuple1
Tuple1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-670ed5017c4d> in <cell line: 5>()
#       3 Tuple1=(12,35,'hgf',13.65, 854)
#       4 del Tuple1
# ----> 5 Tuple1
#
# NameError: name 'Tuple1' is not defined

# %%
##Searching an elemnet in the Tuple
#1)Using in operator

Tuple1=(12,35,'hgf',13.65, 854)
target= 13.65
if target in Tuple1:
  print(f"{target} is in the Tuple")
else:
  print(f"{target} is not in the Tuple")
# Out:
# 13.65 is in the Tuple

# %%
#2)Using linear search
Tuple1=(12,35,'hgf',13.65, 854)
def linearsearch(Tuple1 ,target):
  for i in enumerate(Tuple1):   # i takes index,value takes element
      if  i == target:
        return i
  return -1
print(linearsearch(Tuple1,854))
# Out:
# -1

# %% [markdown]
# ---

# %% [markdown]
# ### Tuple Operations/functions

# %%
# 1.the + symbol ,concatenates two Tuples

a=(1,2,3)
b=(4,7,9)
a+b
# Out:
# [1, 2, 3, 4, 7, 9]

# %%
a=(1,2,3)
b=((4,7,9))
a+b
# Out:
# [1, 2, 3, [4, 7, 9]]

# %%
#2. The Symbol (*) Repeats the Tuple n times

a=(0,1)
a =  a*4
a
# Out:
# [0, 1, 0, 1, 0, 1, 0, 1]

# %%
#len()--> returms total number of elements in the Tuple
#max()--> Returms max value in the Tuple
#min()--> returns minimum value in the Tuple
#sum()--> Returns sum value in a Tuple
#average of Tuple is sum(Tuple)/len(Tuple)
#index()--> returns index value of the given tuple
#count()--> returns number of occurances of a value in a tuple
Tuple1=(12,35,13.65, 854)
print (f'Length of Tuple is {len(Tuple1)}')
print (f'max of Tuple is {max(Tuple1)}')
print (f'min of Tuple is {min(Tuple1)}')
print (f'sum of Tuple is {sum(Tuple1)}')
print (f'sum of Tuple is {sum(Tuple1)/len(Tuple1)}')
# Out:
# Length of list is 4
# max of list is 854
# min of list is 12
# sum of list is 914.65
# sum of list is 228.6625

# %% [markdown]
# ---- listS and Tuple ----
# # similarities
# 1. Both are stored contiguosly in memory
# 2. Both can be indexed and iterated through
# 3. Both can be sliced
# 4. functions that can be used in both lists and tuple are len(),max(),min(), sum(),all(),any(),sorted().
# 5. Tuples can be stored in both list and tuples| Lists can be stored in list and tuples
#
# ---
# # differences
#
# * Tuples are immutable|Lists are mutable
# * Tuples can be renamed but cannot update, replace, delete, or add  elements wheres| lists can do all the operations
# * Slicing in tuple is possible only to access or traverse | lists can change elements in lists using slicing concept
# * Tuples are usually opted for heterogeneous datatypes | Lists are usually opted for homogenious datatypes.
#
# ---

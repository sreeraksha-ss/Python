# %% [markdown]
# # Lists
#
# * Lists are mutable ,ordered collection of items enclosed in closed brackets
# * The elements of lists are also seperated by comma and can hold items of any datatype

# %% [markdown]
# ## Contents
#   ##### 1.Creating an empty list
#   ##### 2.Creating a list with elements
#   ##### 3.Accessing /Traversing the list
#   ##### 4.Update/Insert a list in python
#   ##### 5.Slicing  Concept in list
#   ##### 6.Deletion methods in list
#   ##### 7.Arrays and Lists {similarities and differences}
#
# ---

# %% [markdown]
# ### 1.Creating an empty list

# %%
# with the help of square brackets
empty_list=[]

# %%
# using list()constructor
emp= list()
print(emp)
print(type(emp))
# Out:
# []
# <class 'list'>

# %% [markdown]
# ### 2.Creating a list with elements

# %%
ing=[1,2,3,4,5,6,7]
stg=['ab','bc','cd']
intstr= [1,2,'ab',12.5]
print(type(ing))
print(type(stg))
print(type(intstr))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# ---

# %% [markdown]
# ### 3.Accessing /Traversing the list
#
# Accesing the element can be done either using forward indexing or reverse indexing

# %%
# Accessing

nts= [1,2,'ab',12.5]
print(nts[0])  # forward indexing
print(nts[-2]) # backward indexing
# Out:
# 1
# ab

# %%
#Traversing -->visiting each element atleast once in the list (traversing can be done using for loop)

#method 1 using membership operator in
nts= [1,2,'ab',12.5]
for i in nts:
  print(i)
# Out:
# 1
# 2
# ab
# 12.5

# %%
#method 2 using range and len functions

for i in range(len(nts)):
  nts[i] += nts[i] ,+, str[1]
  print(nts[i])
# Out:
#   File "<ipython-input-12-68177721146e>", line 4
#     nts[i] += nts[i] ,+, str[1]
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ⚡Is it possible to loop towards an empty list?

# %% [markdown]
# ### 4.Update/Insert a list in python

# %%
# Updating elements --> without changing the memoruy location we update a value to a given location

list1=[12,35,'hgf',13.65, 854]
list1[4]='bmw'
list1
# Out:
# [12, 35, 'hgf', 13.65, 'bmw']

# %%
# Updating the elements in place can also be done using slicing operator
# we will learn about slice in next section

list1=[12,35,'hgf',13.65, 854]
list1[0:2]= ['z', 15]
print(list1)
# Out:
# ['z', 15, 'hgf', 13.65, 854]

# %% [markdown]
# **Inserting elements in python list (insert,append,extend)**
#
# Using insert method we can insert value anywhere inthe list using indexing

# %%
#1.Inserting  single Element at the beginning/any given index value in the of the list
# syntax =[list1.insert(index, value)]

list1=[12,35,'hgf',13.65, 854]
list1.insert(1,'ab')
list1
# Out:
# [12, 'ab', 35, 'hgf', 13.65, 854]

# %%
# 2.Append --> used to add single at the end of the list
# Syntax -->(list1.append(value)) # if Str-->'Value'
list1=[12,35,'hgf',13.65, 854]
list1.append('ab1')
list1
# Out:
# [12, 35, 'hgf', 13.65, 854, 'ab1']

# %%
# 2.Append --> does not takes multiple values to append
list1=[12,35,'hgf',13.65, 854]
list1.append('ab1','bab1')
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f8c1a4c99d4e> in <cell line: 3>()
#       1 # 2.Append --> does not takes multiple values to append
#       2 list1=[12,35,'hgf',13.65, 854]
# ----> 3 list1.append('ab1','bab1')
#       4 list1
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
#extend method is used to add list to the list,or more values
#syntax-->(mylist.extend([5,6,7,8]))

list1=[12,35,'hgf',13.65, 854]
list1.extend(['ab1','bab1'])
list1
# Out:
# [12, 35, 'hgf', 13.65, 854, 'ab1', 'bab1']

# %%
# Extend method can add nested list inside a list too
list1=[12,35,'hgf',13.65, 854]
list1.extend([['ccv','ccb1']])
list1
# Out:
# [12, 35, 'hgf', 13.65, 854, ['ccv', 'ccb1']]

# %% [markdown]
# ---extend and append differences--- add

# %% [markdown]
# ### 5.Slicing  Concept in list
#     syntax-->(list1[start:stop:step])

# %%
list1=[12,35,'hgf',13.65, 854]
list1
# Out:
# [12, 35, 'hgf', 13.65, 854]

# %%
# first two elements
print(list1[0:2])
# Out:
# [12, 35]

# %%
#second element to len of list
print(list1[1:])
# Out:
# [35, 'hgf', 13.65, 854]

# %%
# All elements
print(list1[:])
# Out:
# [12, 35, 'hgf', 13.65, 854]

# %%
#In steps of two
print(list1[::2])
# Out:
# [12, 'hgf', 854]

# %%
#reversing the list elements
print(list1[::-1])
# Out:
# [854, 13.65, 'hgf', 35, 12]

# %%
# updating the list elements in place orderly
list1[0:2]= ['z', 15]
print(list1)
# Out:
# ['z', 15, 'hgf', 13.65, 854]

# %% [markdown]
# ---

# %% [markdown]
# ### 6.Deletion methods in list

# %% [markdown]
# **Deletion of elements/list can be done using pop() ,delete() and remove()**

# %%
#pop(i)--> removes the ith index element in the list
#syntax--> list.pop(index)
list1=[12,35,'hgf',13.65, 854]
list1.pop(2)
list1
# Out:
# [12, 35, 13.65, 854]

# %%
#pop()--> removes the last element in the list
#syntax--> list.pop()
list1=[12,35,'hgf',13.65, 854]
list1.pop()
list1
# Out:
# [12, 35, 'hgf', 13.65]

# %%
# delete method works on index and slicing
#syntax--> del list[index]
list1=[12,35,'hgf',13.65, 854]
del list1[3]
list1
# Out:
# [12, 35, 'hgf', 854]

# %%
# delete method works on index and slicing
#syntax--> del list[0:n]
list1=[12,35,'hgf',13.65, 854]
del list1[0:3]
list1
# Out:
# [13.65, 854]

# %%
#delete method works on entire list
#syntax--> del list
list1=[12,35,'hgf',13.65, 854]
del list1
list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a92eab48df08> in <cell line: 5>()
#       3 list1=[12,35,'hgf',13.65, 854]
#       4 del list1
# ----> 5 list1
#
# NameError: name 'list1' is not defined

# %%
#Remove method (works on the element to be remooved if the index value is unknown)
#syntax--> list.remove('element')

list1=[12,35,'hgf',13.65, 854]
list1.remove(35)
list1
# Out:
# [12, 'hgf', 13.65, 854]

# %%
#Remove method (works on the element to be remooved if the index value is unknown)
#syntax--> list.remove('element') #it does not take more than one argument

list1=[12,35,'hgf',13.65, 854]
list1.remove([12,35])
list1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-7198555e52de> in <cell line: 5>()
#       3
#       4 list1=[12,35,'hgf',13.65, 854]
# ----> 5 list1.remove([12,35])
#       6 list1
#
# ValueError: list.remove(x): x not in list

# %%
##Searching an elemnet in the list
#1)Using in operator

list1=[12,35,'hgf',13.65, 854]
target= 13.65
if target in list1:
  print(f"{target} is in the list")
else:
  print(f"{target} is not in the list")
# Out:
# 13.65 is in the list

# %%
#2)Using linear search
list1=[12,35,'hgf',13.65, 854]
def linearsearch(list1 ,target):
  for i , value in enumerate(list1):   # i takes index,value takes element
      if  value == target:
        return i
  return -1
print(linearsearch(list1,854))
# Out:
# 4

# %% [markdown]
# ---

# %% [markdown]
# ### List Operations/functions

# %%
# 1.the + symbol ,concatenates two lists

a=[1,2,3]
b=[4,7,9]
a+b
# Out:
# [1, 2, 3, 4, 7, 9]

# %%
a=[1,2,3]
b=[[4,7,9]]
a+b
# Out:
# [1, 2, 3, [4, 7, 9]]

# %%
#2. The Symbol (*) Repeats the list n times

a=[0,1]
a =  a*4
a
# Out:
# [0, 1, 0, 1, 0, 1, 0, 1]

# %%
#len()--> returms total number of elements in the list
#max()--> Returms max value in the list
#min()--> returns minimum value in the list
#sum()--> Returns sum value in a list
#average of list is sum(list)/len(list)
list1=[12,35,13.65, 854]
print (f'Length of list is {len(list1)}')
print (f'max of list is {max(list1)}')
print (f'min of list is {min(list1)}')
print (f'sum of list is {sum(list1)}')
print (f'sum of list is {sum(list1)/len(list1)}')
# Out:
# Length of list is 4
# max of list is 854
# min of list is 12
# sum of list is 914.65
# sum of list is 228.6625

# %% [markdown]
# ----Array and list ----
# # similarities
# 1. Both data structures are mutable
# 2. Both can be indexed and iterated through
# 3. Both can be sliced
# ---
# # differences
#
# * Array contains same data type elements ,where as list contains all datay type elements
#
# * Array is widely used when math opeations to be performed are more
# ---

# %%
#Numerical operations are much easier to handle in arrays
import numpy as np
Array= np.array([0,1,2,3,4,5])
print(Array/2)
# Out:
# [0.  0.5 1.  1.5 2.  2.5]

# %%
list1= [0,1,2,3,4,5]
print(list1/2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-1db9ebc70969> in <cell line: 2>()
#       1 list1= [0,1,2,3,4,5]
# ----> 2 print(list1/2)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'
